# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from utils import load_data

# %% [markdown]
# # Loading data

# %%
TRAINING_DATA = "cup98LRN.csv"

# %%
raw_data = load_data(TRAINING_DATA)

# %% [markdown]
# # Exploration

# %%
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95412 entries, 0 to 95411
# Columns: 481 entries, ODATEDW to GEOCODE2
# dtypes: float64(97), int64(310), object(74)
# memory usage: 350.1+ MB

# %%
raw_data.head()
# Out:
#    ODATEDW OSOURCE  TCODE STATE    ZIP MAILCODE PVASTATE   DOB NOEXCH  \
# 0     8901     GRI      0    IL  61081                    3712      0
# 1     9401     BOA      1    CA  91326                    5202      0
# 2     9001     AMH      1    NC  27017                       0      0
# 3     8701     BRY      0    CA  95953                    2801      0
# 4     8601              0    FL  33176                    2001      0
#
#   RECINHSE  ... TARGET_D HPHONE_D RFA_2R RFA_2F RFA_2A MDMAUD_R  MDMAUD_F  \
# 0           ...      0.0        0      L      4      E        X         X
# 1           ...      0.0        0      L      2      G        X         X
# 2           ...      0.0        1      L      4      E        X         X
# 3           ...      0.0        1      L      4      E        X         X
# 4        X  ...      0.0        1      L      2      F        X         X
#
#   MDMAUD_A CLUSTER2 GEOCODE2
# 0        X     39.0        C
# 1        X      1.0        A
# ...

# %%
description = raw_data.describe()
description
# Out:
#             ODATEDW         TCODE           DOB           AGE       NUMCHLD  \
# count  95412.000000  95412.000000  95412.000000  71747.000000  12386.000000
# mean    9141.363256     54.223117   2723.602933     61.611649      1.527773
# std      343.454752    953.844476   2132.241295     16.664199      0.806861
# min     8306.000000      0.000000      0.000000      1.000000      1.000000
# 25%     8801.000000      0.000000    201.000000     48.000000      1.000000
# 50%     9201.000000      1.000000   2610.000000     62.000000      1.000000
# 75%     9501.000000      2.000000   4601.000000     75.000000      2.000000
# max     9701.000000  72002.000000   9710.000000     98.000000      7.000000
#
#              INCOME       WEALTH1           HIT       MBCRAFT      MBGARDEN  \
# count  74126.000000  50680.000000  95412.000000  42558.000000  42558.000000
# mean       3.886248      5.345699      3.321438      0.152075      0.059166
# ...

# %%
missing_values = raw_data.isnull().mean()

# %%
missing_values.sort_values(ascending=False)
# Out:
# RDATE_5    0.999906
# RAMNT_5    0.999906
# RDATE_3    0.997464
# RAMNT_3    0.997464
# RDATE_4    0.997055
#              ...
# ETHC3      0.000000
# ETHC2      0.000000
# ETHC1      0.000000
# HHD12      0.000000
# TPE11      0.000000
# Length: 481, dtype: float64

# %%
donations_tf = raw_data["TARGET_B"].to_list()

proportions = np.bincount(donations_tf)/len(donations_tf)

print(f"Percentage of negative classes: {np.round(proportions[0], decimals=4)*100}\nPercentage of positive classes: {np.round(proportions[1], decimals=4)*100}")
# Out:
# Percentage of negative classes: 94.92
# Percentage of positive classes: 5.08

# %%
donation_amount = raw_data["TARGET_D"].to_numpy()

given_donations = donation_amount[donation_amount > 0]

plt.hist(given_donations, bins=20)
plt.title("Donations")
plt.xlabel("Given money")
plt.ylabel("Groups sizes")
plt.show()

# %% [markdown]
# Distribution of given donations is not symmetrical so it is better to use median instead of mean.

# %%
profit_per_donor = np.median(given_donations)
profit_per_donor
# Out:
# 13.0
