# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from utils import *

# %% [markdown]
# # Loading data

# %%
TRAINING_DATA = "cup98LRN.csv"

# %%
raw_data = load_data(TRAINING_DATA)

# %%
raw_data
# Out:
#        ODATEDW OSOURCE  TCODE STATE    ZIP MAILCODE PVASTATE   DOB NOEXCH  \
# 0         8901     GRI      0    IL  61081                    3712      0
# 1         9401     BOA      1    CA  91326                    5202      0
# 2         9001     AMH      1    NC  27017                       0      0
# 3         8701     BRY      0    CA  95953                    2801      0
# 4         8601              0    FL  33176                    2001      0
# ...        ...     ...    ...   ...    ...      ...      ...   ...    ...
# 95407     9601     ASE      1    AK  99504                       0      0
# 95408     9601     DCD      1    TX  77379                    5001      0
# 95409     9501     MBC      1    MI  48910                    3801      0
# 95410     8601     PRV      0    CA  91320                    4005      0
# 95411     8801     MCC      2    NC  28409                    1801      0
#
#       RECINHSE  ... TARGET_D HPHONE_D RFA_2R RFA_2F RFA_2A MDMAUD_R  MDMAUD_F  \
# 0               ...      0.0        0      L      4      E        X         X
# 1               ...      0.0        0      L      2      G        X         X
# 2               ...      0.0        1      L      4      E        X         X
# 3               ...      0.0        1      L      4      E        X         X
# 4            X  ...      0.0        1      L      2      F        X         X
# ...        ...  ...      ...      ...    ...    ...    ...      ...       ...
# 95407           ...      0.0        0      L      1      G        X         X
# 95408           ...      0.0        1      L      1      F        X         X
# 95409           ...      0.0        1      L      3      E        X         X
# 95410        X  ...     18.0        1      L      4      F        X         X
# 95411        X  ...      0.0        1      L      1      G        C         1
#
#       MDMAUD_A CLUSTER2 GEOCODE2
# 0            X     39.0        C
# 1            X      1.0        A
# 2            X     60.0        C
# 3            X     41.0        C
# 4            X     26.0        A
# ...        ...      ...      ...
# 95407        X     12.0        C
# 95408        X      2.0        A
# 95409        X     34.0        B
# 95410        X     11.0        A
# 95411        C     12.0        C
#
# [95412 rows x 481 columns]

# %% [markdown]
# # Data cleaning

# %%
without_duplicates = raw_data.drop_duplicates()

# %%
# filled_data = Preprocessor.fill_nans(without_duplicates)

# %%
filled_data = fill_empty(without_duplicates)

# %%
filled_data
# Out:
#        ODATEDW OSOURCE  TCODE STATE    ZIP MAILCODE PVASTATE   DOB NOEXCH  \
# 0         8901     GRI      0    IL  61081                    3712      0
# 1         9401     BOA      1    CA  91326                    5202      0
# 2         9001     AMH      1    NC  27017                       0      0
# 3         8701     BRY      0    CA  95953                    2801      0
# 4         8601              0    FL  33176                    2001      0
# ...        ...     ...    ...   ...    ...      ...      ...   ...    ...
# 95407     9601     ASE      1    AK  99504                       0      0
# 95408     9601     DCD      1    TX  77379                    5001      0
# 95409     9501     MBC      1    MI  48910                    3801      0
# 95410     8601     PRV      0    CA  91320                    4005      0
# 95411     8801     MCC      2    NC  28409                    1801      0
#
#       RECINHSE  ... TARGET_D HPHONE_D RFA_2R RFA_2F RFA_2A MDMAUD_R  MDMAUD_F  \
# 0               ...      0.0        0      L      4      E        X         X
# 1               ...      0.0        0      L      2      G        X         X
# 2               ...      0.0        1      L      4      E        X         X
# 3               ...      0.0        1      L      4      E        X         X
# 4            X  ...      0.0        1      L      2      F        X         X
# ...        ...  ...      ...      ...    ...    ...    ...      ...       ...
# 95407           ...      0.0        0      L      1      G        X         X
# 95408           ...      0.0        1      L      1      F        X         X
# 95409           ...      0.0        1      L      3      E        X         X
# 95410        X  ...     18.0        1      L      4      F        X         X
# 95411        X  ...      0.0        1      L      1      G        C         1
#
#       MDMAUD_A CLUSTER2 GEOCODE2
# 0            X     39.0        C
# 1            X      1.0        A
# 2            X     60.0        C
# 3            X     41.0        C
# 4            X     26.0        A
# ...        ...      ...      ...
# 95407        X     12.0        C
# 95408        X      2.0        A
# 95409        X     34.0        B
# 95410        X     11.0        A
# 95411        C     12.0        C
#
# [95412 rows x 481 columns]

# %%
filled_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 95412 entries, 0 to 95411
# Columns: 481 entries, ODATEDW to GEOCODE2
# dtypes: float64(97), int64(310), object(74)
# memory usage: 350.9+ MB

# %% [markdown]
# # Feature selection

# %%
training_data = filled_data.drop(["TARGET_D"], axis=1)

# %% [markdown]
# ## Categorical

# %%
object_columns = training_data.select_dtypes(include=['object']).columns

# %%
categorical_features = filled_data[object_columns]

# %%
categorical_features = categorical_features.replace({" ": "-"})
categorical_features
# Out:
#       OSOURCE STATE    ZIP MAILCODE PVASTATE NOEXCH RECINHSE RECP3 RECPGVG  \
# 0         GRI    IL  61081        -        -      0        -     -       -
# 1         BOA    CA  91326        -        -      0        -     -       -
# 2         AMH    NC  27017        -        -      0        -     -       -
# 3         BRY    CA  95953        -        -      0        -     -       -
# 4           -    FL  33176        -        -      0        X     X       -
# ...       ...   ...    ...      ...      ...    ...      ...   ...     ...
# 95407     ASE    AK  99504        -        -      0        -     -       -
# 95408     DCD    TX  77379        -        -      0        -     -       -
# 95409     MBC    MI  48910        -        -      0        -     X       -
# 95410     PRV    CA  91320        -        -      0        X     -       -
# 95411     MCC    NC  28409        -        -      0        X     -       X
#
#       RECSWEEP  ... RFA_21 RFA_22 RFA_23 RFA_24 RFA_2R RFA_2A MDMAUD_R  \
# 0            -  ...    S4E    S4E    S4E    S4E      L      E        X
# 1            -  ...    N1E    N1E      -    F1E      L      G        X
# 2            -  ...      -    S4D    S4D    S3D      L      E        X
# 3            -  ...    A1D    A1D      -      -      L      E        X
# 4            -  ...    A3D    I4E    A3D    A3D      L      F        X
# ...        ...  ...    ...    ...    ...    ...    ...    ...      ...
# 95407        -  ...      -      -      -      -      L      G        X
# 95408        -  ...      -      -      -      -      L      F        X
# 95409        -  ...    P1D    P1D      -      -      L      E        X
# 95410        -  ...    A1F    A1F    S2F    S3F      L      F        X
# 95411        -  ...    S3G    S3G    S3G    S3G      L      G        C
#
#       MDMAUD_F MDMAUD_A GEOCODE2
# 0            X        X        C
# 1            X        X        A
# 2            X        X        C
# 3            X        X        C
# 4            X        X        A
# ...        ...      ...      ...
# 95407        X        X        C
# 95408        X        X        A
# 95409        X        X        B
# 95410        X        X        A
# 95411        1        C        C
#
# [95412 rows x 74 columns]

# %%
categorical_features["TARGET"] = raw_data["TARGET_B"]

# %%
from scipy.stats import chi2_contingency

# %%
alpha = 0.05

dependence = {"Dependent": 0, "Independent": 0}
dependent_columns = []
dep_stat = []
indep_stat = []

for column in categorical_features.columns[:-1]:
    stat, p, _, _ = chi2_contingency(pd.crosstab(index=categorical_features["TARGET"], columns=categorical_features[column]).to_numpy())
    if p <= alpha:
        dependence["Dependent"] += 1
        dependent_columns.append(column)
        dep_stat.append(stat)
    else:
        dependence["Independent"] += 1
        indep_stat.append(stat)

# %%
dependence
# Out:
# {'Dependent': 44, 'Independent': 30}

# %%
categorical_features_important = categorical_features[dependent_columns]
categorical_features_important
# Out:
#       OSOURCE STATE MAILCODE RECINHSE RECP3 DOMAIN CLUSTER HOMEOWNR GENDER  \
# 0         GRI    IL        -        -     -     T2      36        -      F
# 1         BOA    CA        -        -     -     S1      14        H      M
# 2         AMH    NC        -        -     -     R2      43        U      M
# 3         BRY    CA        -        -     -     R2      44        U      F
# 4           -    FL        -        X     X     S2      16        H      F
# ...       ...   ...      ...      ...   ...    ...     ...      ...    ...
# 95407     ASE    AK        -        -     -     C2      27        -      M
# 95408     DCD    TX        -        -     -     C1      24        H      M
# 95409     MBC    MI        -        -     X     C3      30        -      M
# 95410     PRV    CA        -        X     -     C1      24        H      F
# 95411     MCC    NC        -        X     -     C1      24        U      F
#
#       SOLP3  ... RFA_16 RFA_17 RFA_18 RFA_19 RFA_20 RFA_21 RFA_22 RFA_23  \
# 0         -  ...    S4E    S4E    S4E    S4E    S4E    S4E    S4E    S4E
# 1         -  ...    L1E      -      -    N1E    N1E    N1E    N1E      -
# 2         -  ...    S4F      -    S4D    S4D      -      -    S4D    S4D
# 3         -  ...    S4E    S2D    S2D    A1D    A1D    A1D    A1D      -
# 4         -  ...    L3D    A2D    A2D    A3D    A3D    A3D    I4E    A3D
# ...     ...  ...    ...    ...    ...    ...    ...    ...    ...    ...
# 95407     -  ...      -      -      -      -      -      -      -      -
# 95408     -  ...      -      -      -      -      -      -      -      -
# 95409     -  ...    F1D      -    F1D      -      -    P1D    P1D      -
# 95410     -  ...    S3F    S2F    S2F    A1F    A1F    A1F    A1F    S2F
# 95411     -  ...    S2G    S3G    S3G    S4G    S3G    S3G    S3G    S3G
#
#       RFA_24 RFA_2A
# 0        S4E      E
# 1        F1E      G
# 2        S3D      E
# 3          -      E
# 4        A3D      F
# ...      ...    ...
# 95407      -      G
# 95408      -      F
# 95409      -      E
# 95410    S3F      F
# 95411    S3G      G
#
# [95412 rows x 44 columns]

# %%
categorical_features_important_one_hot = pd.get_dummies(categorical_features_important)

# %%
categorical_features_important_one_hot["TARGET"] = raw_data["TARGET_B"]

# %%
alpha = 0.05

dependence = {"Dependent": 0, "Independent": 0}
dependent_columns = []
dep_stat = []
indep_stat = []

for column in categorical_features_important_one_hot.columns[:-1]:
    stat, p, _, _ = chi2_contingency(pd.crosstab(index=categorical_features_important_one_hot["TARGET"], columns=categorical_features_important_one_hot[column]).to_numpy())
    if p <= alpha:
        dependence["Dependent"] += 1
        dependent_columns.append(column)
        dep_stat.append(stat)
    else:
        dependence["Independent"] += 1
        indep_stat.append(stat)

# %%
dependence
# Out:
# {'Dependent': 543, 'Independent': 2633}

# %%
categorical_features_selected = categorical_features_important_one_hot[dependent_columns]

# %% [markdown]
# ## Numerical

# %%
numerical_columns = training_data.select_dtypes(include=['int64', 'float64']).columns

# %%
numerical_features = filled_data[numerical_columns]

# %%
numerical_features["TARGET"] = raw_data["TARGET_B"]
# Out:
# C:\Users\detac\AppData\Local\Temp\ipykernel_15492\2082305672.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   numerical_features["TARGET"] = raw_data["TARGET_B"]

# %%
numerical_features
# Out:
#        ODATEDW  TCODE   DOB        AGE   NUMCHLD    INCOME   WEALTH1  HIT  \
# 0         8901      0  3712  60.000000  1.527773  3.886248  5.345699    0
# 1         9401      1  5202  46.000000  1.000000  6.000000  9.000000   16
# 2         9001      1     0  61.611649  1.527773  3.000000  1.000000    2
# 3         8701      0  2801  70.000000  1.527773  1.000000  4.000000    2
# 4         8601      0  2001  78.000000  1.000000  3.000000  2.000000   60
# ...        ...    ...   ...        ...       ...       ...       ...  ...
# 95407     9601      1     0  61.611649  1.527773  3.886248  5.345699    0
# 95408     9601      1  5001  48.000000  1.000000  7.000000  9.000000    1
# 95409     9501      1  3801  60.000000  1.527773  3.886248  5.345699    0
# 95410     8601      0  4005  58.000000  1.527773  7.000000  5.345699    0
# 95411     8801      2  1801  80.000000  1.527773  5.000000  8.000000    3
#
#         MBCRAFT  MBGARDEN  ...  FISTDATE     NEXTDATE    TIMELAG    AVGGIFT  \
# 0      0.152075  0.059166  ...      8911  9003.000000   4.000000   7.741935
# 1      0.000000  0.000000  ...      9310  9504.000000  18.000000  15.666667
# 2      0.000000  0.000000  ...      9001  9101.000000  12.000000   7.481481
# 3      0.000000  0.000000  ...      8702  8711.000000   9.000000   6.812500
# 4      1.000000  0.000000  ...      7903  8005.000000  14.000000   6.864865
# ...         ...       ...  ...       ...          ...        ...        ...
# 95407  0.152075  0.059166  ...      9602  9151.022917   8.093739  25.000000
# 95408  0.000000  0.000000  ...      9603  9151.022917   8.093739  20.000000
# 95409  0.152075  0.059166  ...      9410  9501.000000   3.000000   8.285714
# 95410  0.152075  0.059166  ...      8612  8704.000000   4.000000  12.146341
# 95411  0.000000  0.000000  ...      8803  8809.000000   6.000000  96.794872
#
#        CONTROLN  TARGET_B  HPHONE_D  RFA_2F  CLUSTER2  TARGET
# 0         95515         0         0       4      39.0       0
# 1        148535         0         0       2       1.0       0
# 2         15078         0         1       4      60.0       0
# 3        172556         0         1       4      41.0       0
# 4          7112         0         1       2      26.0       0
# ...         ...       ...       ...     ...       ...     ...
# 95407    184568         0         0       1      12.0       0
# 95408    122706         0         1       1       2.0       0
# 95409    189641         0         1       3      34.0       0
# 95410      4693         1         1       4      11.0       1
# 95411    185114         0         1       1      12.0       0
#
# [95412 rows x 407 columns]

# %%
corr_matrix = numerical_features.corr(method='pearson')  # TODO: find a method that can avoid overflow

# %%
corr_matrix
# Out:
#            ODATEDW     TCODE       DOB       AGE   NUMCHLD    INCOME  \
# ODATEDW   1.000000 -0.033214  0.099450 -0.265999  0.011992  0.081450
# TCODE    -0.033214  1.000000 -0.003527  0.009662  0.001381 -0.005071
# DOB       0.099450 -0.003527  1.000000 -0.679248  0.042862  0.196965
# AGE      -0.265999  0.009662 -0.679248  1.000000 -0.060705 -0.217127
# NUMCHLD   0.011992  0.001381  0.042862 -0.060705  1.000000  0.008071
# ...            ...       ...       ...       ...       ...       ...
# TARGET_B -0.032270  0.004941 -0.001703  0.007922 -0.005123  0.016425
# HPHONE_D -0.073435 -0.002025  0.076916  0.083355  0.008842 -0.025190
# RFA_2F   -0.065082  0.007835 -0.048517  0.050085  0.007142 -0.070112
# CLUSTER2 -0.060136  0.001131 -0.089796  0.049102 -0.007146 -0.329633
# TARGET   -0.032270  0.004941 -0.001703  0.007922 -0.005123  0.016425
#
#            WEALTH1       HIT   MBCRAFT  MBGARDEN  ...  FISTDATE  NEXTDATE  \
# ODATEDW   0.045445 -0.070752 -0.012176 -0.025678  ...  0.976866  0.868699
# TCODE    -0.004569 -0.002897 -0.000731 -0.003981  ... -0.033189 -0.028842
# DOB       0.081192  0.023451  0.008830 -0.007219  ...  0.098443  0.109837
# AGE      -0.081003  0.115603  0.005810  0.017893  ... -0.264007 -0.254353
# NUMCHLD   0.008820  0.001156  0.009571 -0.002331  ...  0.011402  0.016696
# ...            ...       ...       ...       ...  ...       ...       ...
# TARGET_B  0.008252  0.006189  0.009001 -0.000497  ... -0.032701 -0.024770
# HPHONE_D -0.010760  0.213498  0.009925  0.007290  ... -0.071569 -0.061333
# RFA_2F   -0.038266 -0.000448  0.009740  0.003812  ... -0.068630  0.042276
# CLUSTER2 -0.474659 -0.053944  0.011969  0.039827  ... -0.060033 -0.056925
# TARGET    0.008252  0.006189  0.009001 -0.000497  ... -0.032701 -0.024770
#
#            TIMELAG   AVGGIFT  CONTROLN  TARGET_B  HPHONE_D    RFA_2F  \
# ODATEDW  -0.078963  0.216869  0.079036 -0.032270 -0.073435 -0.065082
# TCODE     0.004956 -0.005778 -0.001920  0.004941 -0.002025  0.007835
# DOB       0.019413  0.020828 -0.023648 -0.001703  0.076916 -0.048517
# AGE      -0.007321 -0.063872 -0.024782  0.007922  0.083355  0.050085
# NUMCHLD  -0.002965 -0.005604  0.001480 -0.005123  0.008842  0.007142
# ...            ...       ...       ...       ...       ...       ...
# TARGET_B -0.010260 -0.032444  0.013165  1.000000 -0.002626  0.072311
# HPHONE_D  0.008395 -0.044323 -0.108747 -0.002626  1.000000  0.007607
# RFA_2F   -0.127265 -0.277168 -0.016545  0.072311  0.007607  1.000000
# CLUSTER2 -0.015064 -0.077235 -0.143244 -0.016390 -0.018303  0.043029
# TARGET   -0.010260 -0.032444  0.013165  1.000000 -0.002626  0.072311
#
#           CLUSTER2    TARGET
# ODATEDW  -0.060136 -0.032270
# TCODE     0.001131  0.004941
# DOB      -0.089796 -0.001703
# AGE       0.049102  0.007922
# NUMCHLD  -0.007146 -0.005123
# ...            ...       ...
# TARGET_B -0.016390  1.000000
# HPHONE_D -0.018303 -0.002626
# RFA_2F    0.043029  0.072311
# CLUSTER2  1.000000 -0.016390
# TARGET   -0.016390  1.000000
#
# [407 rows x 407 columns]

# %%
corr_matrix_columns = corr_matrix.columns

# %%
correlated_features = []
for i in range(corr_matrix.shape[0]):
    for j in range(corr_matrix.shape[1]):
        if corr_matrix.iloc[i, j] >= .9 and corr_matrix.iloc[i, j] != 1.:
            correlated_features.append([corr_matrix_columns[i], corr_matrix_columns[j]])

# %%
len(correlated_features)
# Out:
# 184

# %%
correlated_features_without_duplicates = []
for pair in correlated_features:
    if [pair[1], pair[0]] not in correlated_features_without_duplicates:
        correlated_features_without_duplicates.append(pair)

# %%
redundant_features = []
for features in correlated_features_without_duplicates:
    redundant_features.append(features[0])

# %%
numerical_features
# Out:
#        ODATEDW  TCODE   DOB        AGE   NUMCHLD    INCOME   WEALTH1  HIT  \
# 0         8901      0  3712  60.000000  1.527773  3.886248  5.345699    0
# 1         9401      1  5202  46.000000  1.000000  6.000000  9.000000   16
# 2         9001      1     0  61.611649  1.527773  3.000000  1.000000    2
# 3         8701      0  2801  70.000000  1.527773  1.000000  4.000000    2
# 4         8601      0  2001  78.000000  1.000000  3.000000  2.000000   60
# ...        ...    ...   ...        ...       ...       ...       ...  ...
# 95407     9601      1     0  61.611649  1.527773  3.886248  5.345699    0
# 95408     9601      1  5001  48.000000  1.000000  7.000000  9.000000    1
# 95409     9501      1  3801  60.000000  1.527773  3.886248  5.345699    0
# 95410     8601      0  4005  58.000000  1.527773  7.000000  5.345699    0
# 95411     8801      2  1801  80.000000  1.527773  5.000000  8.000000    3
#
#         MBCRAFT  MBGARDEN  ...  FISTDATE     NEXTDATE    TIMELAG    AVGGIFT  \
# 0      0.152075  0.059166  ...      8911  9003.000000   4.000000   7.741935
# 1      0.000000  0.000000  ...      9310  9504.000000  18.000000  15.666667
# 2      0.000000  0.000000  ...      9001  9101.000000  12.000000   7.481481
# 3      0.000000  0.000000  ...      8702  8711.000000   9.000000   6.812500
# 4      1.000000  0.000000  ...      7903  8005.000000  14.000000   6.864865
# ...         ...       ...  ...       ...          ...        ...        ...
# 95407  0.152075  0.059166  ...      9602  9151.022917   8.093739  25.000000
# 95408  0.000000  0.000000  ...      9603  9151.022917   8.093739  20.000000
# 95409  0.152075  0.059166  ...      9410  9501.000000   3.000000   8.285714
# 95410  0.152075  0.059166  ...      8612  8704.000000   4.000000  12.146341
# 95411  0.000000  0.000000  ...      8803  8809.000000   6.000000  96.794872
#
#        CONTROLN  TARGET_B  HPHONE_D  RFA_2F  CLUSTER2  TARGET
# 0         95515         0         0       4      39.0       0
# 1        148535         0         0       2       1.0       0
# 2         15078         0         1       4      60.0       0
# 3        172556         0         1       4      41.0       0
# 4          7112         0         1       2      26.0       0
# ...         ...       ...       ...     ...       ...     ...
# 95407    184568         0         0       1      12.0       0
# 95408    122706         0         1       1       2.0       0
# 95409    189641         0         1       3      34.0       0
# 95410      4693         1         1       4      11.0       1
# 95411    185114         0         1       1      12.0       0
#
# [95412 rows x 407 columns]

# %%
numerical_features = numerical_features.drop(redundant_features, axis=1)
numerical_features
# Out:
#        TCODE   DOB        AGE   NUMCHLD    INCOME   WEALTH1  HIT   MBCRAFT  \
# 0          0  3712  60.000000  1.527773  3.886248  5.345699    0  0.152075
# 1          1  5202  46.000000  1.000000  6.000000  9.000000   16  0.000000
# 2          1     0  61.611649  1.527773  3.000000  1.000000    2  0.000000
# 3          0  2801  70.000000  1.527773  1.000000  4.000000    2  0.000000
# 4          0  2001  78.000000  1.000000  3.000000  2.000000   60  1.000000
# ...      ...   ...        ...       ...       ...       ...  ...       ...
# 95407      1     0  61.611649  1.527773  3.886248  5.345699    0  0.152075
# 95408      1  5001  48.000000  1.000000  7.000000  9.000000    1  0.000000
# 95409      1  3801  60.000000  1.527773  3.886248  5.345699    0  0.152075
# 95410      0  4005  58.000000  1.527773  7.000000  5.345699    0  0.152075
# 95411      2  1801  80.000000  1.527773  5.000000  8.000000    3  0.000000
#
#        MBGARDEN   MBBOOKS  ...  FISTDATE     NEXTDATE    TIMELAG    AVGGIFT  \
# 0      0.059166  1.116382  ...      8911  9003.000000   4.000000   7.741935
# 1      0.000000  3.000000  ...      9310  9504.000000  18.000000  15.666667
# 2      0.000000  1.000000  ...      9001  9101.000000  12.000000   7.481481
# 3      0.000000  0.000000  ...      8702  8711.000000   9.000000   6.812500
# 4      0.000000  9.000000  ...      7903  8005.000000  14.000000   6.864865
# ...         ...       ...  ...       ...          ...        ...        ...
# 95407  0.059166  1.116382  ...      9602  9151.022917   8.093739  25.000000
# 95408  0.000000  1.000000  ...      9603  9151.022917   8.093739  20.000000
# 95409  0.059166  1.116382  ...      9410  9501.000000   3.000000   8.285714
# 95410  0.059166  1.116382  ...      8612  8704.000000   4.000000  12.146341
# 95411  0.000000  0.000000  ...      8803  8809.000000   6.000000  96.794872
#
#        CONTROLN  TARGET_B  HPHONE_D  RFA_2F  CLUSTER2  TARGET
# 0         95515         0         0       4      39.0       0
# 1        148535         0         0       2       1.0       0
# 2         15078         0         1       4      60.0       0
# 3        172556         0         1       4      41.0       0
# 4          7112         0         1       2      26.0       0
# ...         ...       ...       ...     ...       ...     ...
# 95407    184568         0         0       1      12.0       0
# 95408    122706         0         1       1       2.0       0
# 95409    189641         0         1       3      34.0       0
# 95410      4693         1         1       4      11.0       1
# 95411    185114         0         1       1      12.0       0
#
# [95412 rows x 351 columns]

# %%
corr_matrix2 = numerical_features.corr(method='pearson')
corr_matrix_target = corr_matrix2["TARGET"].sort_values(ascending=False)

# %%
abs(corr_matrix_target.sort_values(ascending=False))
# Out:
# TARGET      1.000000
# TARGET_B    1.000000
# RFA_2F      0.072311
# CARDGIFT    0.054027
# LASTDATE    0.041158
#               ...
# AVGGIFT     0.032444
# FISTDATE    0.032701
# LASTGIFT    0.035526
# ADATE_5          NaN
# ADATE_15         NaN
# Name: TARGET, Length: 351, dtype: float64

# %%
numerical_features = numerical_features.drop(["ADATE_5", "ADATE_15", "TARGET_B", "TARGET"], axis=1)

# %% [markdown]
# # Saving data

# %%
categorical_features_selected.to_csv("categorical_features.csv")

# %%
numerical_features.to_csv("numerical_features.csv")

# %%
raw_data["TARGET_B"].to_csv("targets.csv")
